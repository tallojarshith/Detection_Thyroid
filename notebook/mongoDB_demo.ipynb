# %%
import numpy

# %%
mongodb+srv://tallojarshith:tallojarshith@cluster0.a0ndpdv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %%
import pandas as pd

# %%
df=pd.read_csv("hypothyroid_data.csv")

# %%
df.head()
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41.0   F            f                  f                         f    f
# 1  23.0   F            f                  f                         f    f
# 2  46.0   M            f                  f                         f    f
# 3  70.0   F            t                  f                         f    f
# 4  70.0   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  ... TT4_measured  \
# 0        f               f              f                 f  ...            t
# 1        f               f              f                 f  ...            t
# 2        f               f              f                 f  ...            t
# 3        f               f              f                 f  ...            t
# 4        f               f              f                 f  ...            t
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'sex', 'on_thyroxine', 'query_on_thyroxine',
#        'on_antithyroid_medication', 'sick', 'pregnant', 'thyroid_surgery',
#        'I131_treatment', 'query_hypothyroid', 'query_hyperthyroid', 'lithium',
#        'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH_measured', 'TSH',
#        'T3_measured', 'T3', 'TT4_measured', 'TT4', 'T4U_measured', 'T4U',
#        'FTI_measured', 'FTI', 'TBG_measured', 'TBG', 'referral_source',
#        'Class'],
#       dtype='object')

# %%
data=df.to_dict(orient="records")

# %%
data
# Out:
# [{'age': 41.0,
#   'sex': 'F',
#   'on_thyroxine': 'f',
#   'query_on_thyroxine': 'f',
#   'on_antithyroid_medication': 'f',
#   'sick': 'f',
#   'pregnant': 'f',
#   'thyroid_surgery': 'f',
#   'I131_treatment': 'f',
#   'query_hypothyroid': 'f',
#   'query_hyperthyroid': 'f',
#   'lithium': 'f',
#   'goitre': 'f',
#   'tumor': 'f',
#   'hypopituitary': 'f',
#   'psych': 'f',
#   'TSH_measured': 't',
#   'TSH': 1.3,
#   'T3_measured': 't',
#   'T3': 2.5,
#   'TT4_measured': 't',
#   'TT4': 125.0,
#   'T4U_measured': 't',
#   'T4U': 1.14,
#   'FTI_measured': 't',
#   'FTI': 109.0,
#   'TBG_measured': 'f',
#   'TBG': nan,
#   'referral_source': 'SVHC',
#   'Class': 'negative'},
#  {'age': 23.0,
#   'sex': 'F',
#   'on_thyroxine': 'f',
#   'query_on_thyroxine': 'f',
#   'on_antithyroid_medication': 'f',
#   'sick': 'f',
#   'pregnant': 'f',
#   'thyroid_surgery': 'f',
#   'I131_treatment': 'f',
#   'query_hypothyroid': 'f',
#   'query_hyperthyroid': 'f',
#   'lithium': 'f',
# ...

# %%
DB_NAME="thyroid_detection"
COLLECTION_NAME="thyroid_data"
CONNECTION_URL="mongodb+srv://tallojarshith:tallojarshith@cluster0.a0ndpdv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo
import certifi
client=pymongo.MongoClient(CONNECTION_URL,tlsCAFile=certifi.where())
data_base=client[DB_NAME]
collection=data_base[COLLECTION_NAME]
rec=collection.insert_many(data)

# %%
rec
# Out:
# InsertManyResult([ObjectId('66570d73bdffbcc0c58caf3c'), ObjectId('66570d73bdffbcc0c58caf3d'), ObjectId('66570d73bdffbcc0c58caf3e'), ObjectId('66570d73bdffbcc0c58caf3f'), ObjectId('66570d73bdffbcc0c58caf40'), ObjectId('66570d73bdffbcc0c58caf41'), ObjectId('66570d73bdffbcc0c58caf42'), ObjectId('66570d73bdffbcc0c58caf43'), ObjectId('66570d73bdffbcc0c58caf44'), ObjectId('66570d73bdffbcc0c58caf45'), ObjectId('66570d73bdffbcc0c58caf46'), ObjectId('66570d73bdffbcc0c58caf47'), ObjectId('66570d73bdffbcc0c58caf48'), ObjectId('66570d73bdffbcc0c58caf49'), ObjectId('66570d73bdffbcc0c58caf4a'), ObjectId('66570d73bdffbcc0c58caf4b'), ObjectId('66570d73bdffbcc0c58caf4c'), ObjectId('66570d73bdffbcc0c58caf4d'), ObjectId('66570d73bdffbcc0c58caf4e'), ObjectId('66570d73bdffbcc0c58caf4f'), ObjectId('66570d73bdffbcc0c58caf50'), ObjectId('66570d73bdffbcc0c58caf51'), ObjectId('66570d73bdffbcc0c58caf52'), ObjectId('66570d73bdffbcc0c58caf53'), ObjectId('66570d73bdffbcc0c58caf54'), ObjectId('66570d73bdffbcc0c58c
# ...

# %%
records=collection.find()

# %%
for i,j in enumerate(records):
    print(f"{i}:{j}")
# Out:
# 0:{'_id': ObjectId('66570d73bdffbcc0c58caf3c'), 'age': 41.0, 'sex': 'F', 'on_thyroxine': 'f', 'query_on_thyroxine': 'f', 'on_antithyroid_medication': 'f', 'sick': 'f', 'pregnant': 'f', 'thyroid_surgery': 'f', 'I131_treatment': 'f', 'query_hypothyroid': 'f', 'query_hyperthyroid': 'f', 'lithium': 'f', 'goitre': 'f', 'tumor': 'f', 'hypopituitary': 'f', 'psych': 'f', 'TSH_measured': 't', 'TSH': 1.3, 'T3_measured': 't', 'T3': 2.5, 'TT4_measured': 't', 'TT4': 125.0, 'T4U_measured': 't', 'T4U': 1.14, 'FTI_measured': 't', 'FTI': 109.0, 'TBG_measured': 'f', 'TBG': nan, 'referral_source': 'SVHC', 'Class': 'negative'}
# ...

# %%
df=pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
#                         _id   age sex on_thyroxine query_on_thyroxine  \
# 0  66570d73bdffbcc0c58caf3c  41.0   F            f                  f
# 1  66570d73bdffbcc0c58caf3d  23.0   F            f                  f
# 2  66570d73bdffbcc0c58caf3e  46.0   M            f                  f
# 3  66570d73bdffbcc0c58caf3f  70.0   F            t                  f
# 4  66570d73bdffbcc0c58caf40  70.0   F            f                  f
#
#   on_antithyroid_medication sick pregnant thyroid_surgery I131_treatment  ...  \
# 0                         f    f        f               f              f  ...
# 1                         f    f        f               f              f  ...
# 2                         f    f        f               f              f  ...
# 3                         f    f        f               f              f  ...
# 4                         f    f        f               f              f  ...
#
# ...

# %%
if "_id" in df.columns.to_list():
    df=df.drop(columns=["_id"],axis=1)

# %%
df.head()
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41.0   F            f                  f                         f    f
# 1  23.0   F            f                  f                         f    f
# 2  46.0   M            f                  f                         f    f
# 3  70.0   F            t                  f                         f    f
# 4  70.0   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  ... TT4_measured  \
# 0        f               f              f                 f  ...            t
# 1        f               f              f                 f  ...            t
# 2        f               f              f                 f  ...            t
# 3        f               f              f                 f  ...            t
# 4        f               f              f                 f  ...            t
#
# ...
